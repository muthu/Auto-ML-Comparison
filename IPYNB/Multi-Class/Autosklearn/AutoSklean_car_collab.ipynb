# %%
# %pip install auto-sklearn
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.14.6.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 4.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (57.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (4.2.0)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.21.6)
# Collecting scipy>=1.7.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.3 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.1.0)
# Collecting scikit-learn<0.25.0,>=0.24.0
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 56.7 MB/s
# Collecting dask>=2021.12
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 40.5 MB/s
# Collecting distributed>=2012.12
#   Downloading distributed-2022.2.0-py3-none-any.whl (837 kB)
#      |████████████████████████████████| 837 kB 48.8 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (3.13)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.3.5)
# Collecting liac-arff
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (3.1.0)
# Collecting ConfigSpace<0.5,>=0.4.14
#   Downloading ConfigSpace-0.4.21-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 31.3 MB/s
# Collecting pynisher>=0.6.3
#   Downloading pynisher-0.6.4.tar.gz (11 kB)
# Collecting pyrfr<0.9,>=0.8.1
#   Downloading pyrfr-0.8.2-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 28.7 MB/s
# Collecting smac>=0.14
#   Downloading smac-1.3.1.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 47.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace<0.5,>=0.4.14->auto-sklearn) (3.0.8)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace<0.5,>=0.4.14->auto-sklearn) (0.29.28)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (21.3)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 48.2 MB/s
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (1.3.0)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 48.2 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.11.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (7.1.2)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (5.4.8)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (5.1.1)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->auto-sklearn) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->auto-sklearn) (1.15.0)
# Collecting smac>=0.14
#   Downloading smac-1.2.tar.gz (260 kB)
#      |████████████████████████████████| 260 kB 46.3 MB/s
# Collecting emcee>=3.0.0
#   Downloading emcee-3.1.1-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.0 MB/s
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2012.12->auto-sklearn) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2012.12->auto-sklearn) (2.0.1)
# Building wheels for collected packages: auto-sklearn, pynisher, smac, liac-arff
#   Building wheel for auto-sklearn (setup.py) ... done
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.14.6-py3-none-any.whl size=6602835 sha256=968e0dbe7cc9054ce1cdf9cf51b908c107de11000f44c23ad1afbef3bf50fc03
#   Stored in directory: /root/.cache/pip/wheels/6a/70/48/db9c00457f87a751083ca0d5c99bf34387dde818c705bd9800
#   Building wheel for pynisher (setup.py) ... done
#   Created wheel for pynisher: filename=pynisher-0.6.4-py3-none-any.whl size=7043 sha256=5701b1e1e58278e1af1cfdee19ff20c61234aeacf96db06a3201b1199194c503
#   Stored in directory: /root/.cache/pip/wheels/42/71/95/7555ec3253e1ba8add72ae5febf1b015d297f3b73ba296d6f6
#   Building wheel for smac (setup.py) ... done
#   Created wheel for smac: filename=smac-1.2-py3-none-any.whl size=215935 sha256=30125bac73f206636b8f0201eea87957f2bc2248b31ec9733bf7f808dc084f68
#   Stored in directory: /root/.cache/pip/wheels/ad/95/67/6afc6b04d3715070c853d0a9d7c7b1fb822def38671dfbbb9f
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11732 sha256=a9814e0b25121347890461116f9a7cd99b7aac9f96968d9e234fd639c9d8ed87
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built auto-sklearn pynisher smac liac-arff
# Installing collected packages: locket, pyyaml, partd, fsspec, cloudpickle, scipy, dask, scikit-learn, pyrfr, pynisher, emcee, distributed, ConfigSpace, smac, liac-arff, distro, auto-sklearn
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.21 auto-sklearn-0.14.6 cloudpickle-2.0.0 dask-2022.2.0 distributed-2022.2.0 distro-1.7.0 emcee-3.1.1 fsspec-2022.3.0 liac-arff-2.5.0 locket-1.0.0 partd-1.2.0 pynisher-0.6.4 pyrfr-0.8.2 pyyaml-6.0 scikit-learn-0.24.2 scipy-1.7.3 smac-1.2

# %%
import sklearn.datasets
import sklearn.model_selection
import autosklearn.classification
import autosklearn.metrics
import pandas as pd

# %%
def dataSetup(name):
  X,y = sklearn.datasets.fetch_openml(data_id = name, as_frame=True, return_X_y=True)
  train = pd.concat([X, y], axis=1, join='inner')
  train.dropna()
  train = train.apply(lambda x: pd.factorize(x)[0])
  X,y = train.iloc[:,:-1], train.iloc[:, -1]
  # X = X.apply(lambda x: pd.factorize(x)[0])
  X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,random_state=42)
  return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = dataSetup(40975)
X_train.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 1036       2      1      2        1         0       1
# 757        1      3      0        0         0       1
# 589        1      1      1        2         1       1
# 907        2      0      1        1         2       1
# 1159       2      2      2        2         2       1

# %%
estimator_askl = autosklearn.classification.AutoSklearnClassifier(time_left_for_this_task=3600,seed=42,resampling_strategy='cv',)
estimator_askl.fit(X_train, y_train, dataset_name='car')
prediction = estimator_askl.predict(X_test)

# %%
(prediction == y_test).sum()/len(prediction)
# Out:
# 0.9791666666666666

# %%
print(estimator_askl.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: car
#   Metric: accuracy
#   Best validation score: 0.998457
#   Number of target algorithm runs: 220
#   Number of successful target algorithm runs: 218
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 0

# %%
from pprint import pprint
pprint(estimator_askl.show_models(), indent=4)
# Out:
# {   43: {   'cost': 0.0023148148148148103,
#             'ensemble_weight': 0.04,
#             'estimators': [   {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e2762590>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e51d9050>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e275bdd0>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.268842963809998e-09,
#                                learning_rate=0.09814042923887036, max_iter=512,
#                                max_leaf_nodes=23, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e3bd9c90>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e3bbfd90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e3bd9890>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.268842963809998e-09,
#                                learning_rate=0.09814042923887036, max_iter=512,
#                                max_leaf_nodes=23, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e3597690>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e357c750>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e3597210>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.268842963809998e-09,
#                                learning_rate=0.09814042923887036, max_iter=512,
#                                max_leaf_nodes=23, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e2e774d0>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e2edc5d0>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e2e72fd0>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.268842963809998e-09,
#                                learning_rate=0.09814042923887036, max_iter=512,
#                                max_leaf_nodes=23, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e28d6c10>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e28bbcd0>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e28d6810>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=2.268842963809998e-09,
#                                learning_rate=0.09814042923887036, max_iter=512,
#                                max_leaf_nodes=23, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)}],
#             'model_id': 43,
#             'rank': 3,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     48: {   'cost': 0.0023148148148148103,
#             'ensemble_weight': 0.04,
#             'estimators': [   {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e1d13f50>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e274c090>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e1d13e10>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.10914822057973764, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=31,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e3735610>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e3796290>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e37354d0>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.10914822057973764, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=31,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e2cff8d0>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e2d60550>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e2cff790>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.10914822057973764, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=31,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e1d6d150>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e1dd6750>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e1d6d090>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.10914822057973764, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=31,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e0ed4510>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e0eff910>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e0ed4490>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.10914822057973764, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=31,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)}],
#             'model_id': 48,
#             'rank': 4,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     52: {   'cost': 0.0030864197530864135,
#             'ensemble_weight': 0.06,
#             'estimators': [   {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dbacd050>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dc212110>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dbac8e90>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.501217087667451e-08,
#                                learning_rate=0.04778124892519126, max_iter=512,
#                                max_leaf_nodes=25, min_samples_leaf=26,
#                                random_state=42,
#                                validation_fraction=0.1124317307495707,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72de69ae10>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72debf2ad0>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72de69ac90>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.501217087667451e-08,
#                                learning_rate=0.04778124892519126, max_iter=512,
#                                max_leaf_nodes=25, min_samples_leaf=26,
#                                random_state=42,
#                                validation_fraction=0.1124317307495707,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dce99790>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dce70590>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dce994d0>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.501217087667451e-08,
#                                learning_rate=0.04778124892519126, max_iter=512,
#                                max_leaf_nodes=25, min_samples_leaf=26,
#                                random_state=42,
#                                validation_fraction=0.1124317307495707,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dbaef950>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dbb54d90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dbaef890>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.501217087667451e-08,
#                                learning_rate=0.04778124892519126, max_iter=512,
#                                max_leaf_nodes=25, min_samples_leaf=26,
#                                random_state=42,
#                                validation_fraction=0.1124317307495707,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db30e750>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db2f8d90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db30e650>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.501217087667451e-08,
#                                learning_rate=0.04778124892519126, max_iter=256,
#                                max_leaf_nodes=25, min_samples_leaf=26,
#                                random_state=42,
#                                validation_fraction=0.1124317307495707,
#                                warm_start=True)}],
#             'model_id': 52,
#             'rank': 14,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     63: {   'cost': 0.0030864197530864135,
#             'ensemble_weight': 0.04,
#             'estimators': [   {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72daddd550>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dbab7150>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dadd7d90>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=6.598011041664723e-09,
#                                learning_rate=0.09659576650387433, max_iter=512,
#                                max_leaf_nodes=21, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e02e0b10>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e064e950>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e02d6150>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=6.598011041664723e-09,
#                                learning_rate=0.09659576650387433, max_iter=512,
#                                max_leaf_nodes=21, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dcd5f890>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dcda5610>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dcd5af50>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=6.598011041664723e-09,
#                                learning_rate=0.09659576650387433, max_iter=512,
#                                max_leaf_nodes=21, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db3b1d10>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db418e10>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db3b1910>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=6.598011041664723e-09,
#                                learning_rate=0.09659576650387433, max_iter=512,
#                                max_leaf_nodes=21, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72da2cee90>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dadc0d50>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72da2cec10>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=6.598011041664723e-09,
#                                learning_rate=0.09659576650387433, max_iter=512,
#                                max_leaf_nodes=21, min_samples_leaf=18,
#                                random_state=42, validation_fraction=None,
#                                warm_start=True)}],
#             'model_id': 63,
#             'rank': 15,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     64: {   'cost': 0.0038580246913580154,
#             'ensemble_weight': 0.02,
#             'estimators': [   {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d0ae4050>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d15d0150>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d0ae0c50>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=28, min_samples_leaf=43,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d749d6d0>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d7ff1650>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d7493a50>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=28, min_samples_leaf=43,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d23a7910>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d237e450>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d23a7650>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=28, min_samples_leaf=43,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d16a6250>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d1682cd0>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d16a1e50>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=28, min_samples_leaf=43,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d05d5e10>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d05ca390>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d05d5c90>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=28, min_samples_leaf=43,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#             'model_id': 64,
#             'rank': 32,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     94: {   'cost': 0.0030864197530864135,
#             'ensemble_weight': 0.04,
#             'estimators': [   {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db251ad0>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dadc5190>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db2511d0>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=256,
#                                max_leaf_nodes=22, min_samples_leaf=40,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=0.12508816388284497,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dc0ee790>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dc13cf90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dc0ee050>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=128,
#                                max_leaf_nodes=22, min_samples_leaf=40,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=0.12508816388284497,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72df821d50>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dfa537d0>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72df818d90>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=40,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=0.12508816388284497,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dc461250>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dc4a3e90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dc45c790>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=256,
#                                max_leaf_nodes=22, min_samples_leaf=40,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=0.12508816388284497,
#                                warm_start=True)},
#                               {   'balancing': Balancing(random_state=42),
#                                   'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db3d6490>,
#                                   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db3b9050>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db3d2f10>,
#                                   'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.9966517649804466e-07,
#                                learning_rate=0.1384275296836449, max_iter=256,
#                                max_leaf_nodes=22, min_samples_leaf=40,
#                                n_iter_no_change=12, random_state=42,
#                                validation_fraction=0.12508816388284497,
#                                warm_start=True)}],
#             'model_id': 94,
#             'rank': 16,
#             'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     100: {   'cost': 0.0030864197530864135,
#              'ensemble_weight': 0.02,
#              'estimators': [   {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72da10b590>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db235350>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72da106e10>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.09694813291040548, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=35,
#                                n_iter_no_change=1, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e0273690>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e3b37490>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e02db350>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.09694813291040548, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=35,
#                                n_iter_no_change=1, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db4f0910>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db547090>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db4f01d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.09694813291040548, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=35,
#                                n_iter_no_change=1, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d97e2a10>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d9f45c10>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d97e2790>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.09694813291040548, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=35,
#                                n_iter_no_change=1, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d94e87d0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d951c9d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d94e8550>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.09694813291040548, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=35,
#                                n_iter_no_change=1, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 100,
#              'rank': 17,
#              'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     101: {   'cost': 0.0030864197530864135,
#              'ensemble_weight': 0.04,
#              'estimators': [   {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db2e9ed0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72da0f33d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db2e3c90>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.14730133004938373, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=18,
#                                n_iter_no_change=13, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dd186450>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dd7c3d90>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dd769ad0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.14730133004938373, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=18,
#                                n_iter_no_change=13, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d97a99d0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d9796d90>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d97a9650>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.14730133004938373, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=18,
#                                n_iter_no_change=13, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d8d73910>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d8dadb10>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d8d73690>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.14730133004938373, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=18,
#                                n_iter_no_change=13, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d89c3210>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d89f3410>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d89adf50>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3126459425513608e-07,
#                                learning_rate=0.14730133004938373, max_iter=512,
#                                max_leaf_nodes=22, min_samples_leaf=18,
#                                n_iter_no_change=13, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 101,
#              'rank': 18,
#              'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     106: {   'cost': 0.0023148148148148103,
#              'ensemble_weight': 0.02,
#              'estimators': [   {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e213dbd0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e1d02150>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e213d250>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3658616352738427e-07,
#                                learning_rate=0.1415266479428735, max_iter=512,
#                                max_leaf_nodes=35, min_samples_leaf=48,
#                                n_iter_no_change=11, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e338cd10>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e33e3450>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e338c4d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3658616352738427e-07,
#                                learning_rate=0.1415266479428735, max_iter=512,
#                                max_leaf_nodes=35, min_samples_leaf=48,
#                                n_iter_no_change=11, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e1e90dd0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e1e77ed0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e1e909d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3658616352738427e-07,
#                                learning_rate=0.1415266479428735, max_iter=512,
#                                max_leaf_nodes=35, min_samples_leaf=48,
#                                n_iter_no_change=11, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e0d39810>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e0da5b90>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e0d394d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3658616352738427e-07,
#                                learning_rate=0.1415266479428735, max_iter=512,
#                                max_leaf_nodes=35, min_samples_leaf=48,
#                                n_iter_no_change=11, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72e0376390>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72e0427590>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72e0376110>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.3658616352738427e-07,
#                                learning_rate=0.1415266479428735, max_iter=512,
#                                max_leaf_nodes=35, min_samples_leaf=48,
#                                n_iter_no_change=11, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 106,
#              'rank': 5,
# ...
#              'estimators': [   {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dc227450>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dcc850d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dc221cd0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=4.813657372156947e-07,
#                                learning_rate=0.10656458413397318, max_iter=512,
#                                max_leaf_nodes=26, min_samples_leaf=59,
#                                n_iter_no_change=9, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72df0b04d0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72df56a9d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72df0ac7d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=4.813657372156947e-07,
#                                learning_rate=0.10656458413397318, max_iter=512,
#                                max_leaf_nodes=26, min_samples_leaf=59,
#                                n_iter_no_change=9, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72dcdc5dd0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72dce24750>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72dcdc5790>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=4.813657372156947e-07,
#                                learning_rate=0.10656458413397318, max_iter=512,
#                                max_leaf_nodes=26, min_samples_leaf=59,
#                                n_iter_no_change=9, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db535a10>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db56fcd0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db535790>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=4.813657372156947e-07,
#                                learning_rate=0.10656458413397318, max_iter=512,
#                                max_leaf_nodes=26, min_samples_leaf=59,
#                                n_iter_no_change=9, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72db087710>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72db0b89d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72db087490>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=4.813657372156947e-07,
#                                learning_rate=0.10656458413397318, max_iter=512,
#                                max_leaf_nodes=26, min_samples_leaf=59,
#                                n_iter_no_change=9, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 211,
#              'rank': 13,
#              'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     212: {   'cost': 0.0030864197530864135,
#              'ensemble_weight': 0.04,
#              'estimators': [   {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d22e6550>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d2aef290>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d22dfd50>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.6510817928179784e-07,
#                                learning_rate=0.1305311350875627, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=43,
#                                n_iter_no_change=0, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d4c9c9d0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d4ce6f50>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d4c97e90>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.6510817928179784e-07,
#                                learning_rate=0.1305311350875627, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=43,
#                                n_iter_no_change=0, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d2431c50>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d2572e90>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d24317d0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.6510817928179784e-07,
#                                learning_rate=0.1305311350875627, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=43,
#                                n_iter_no_change=0, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d19bebd0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d19ae390>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d19be890>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.6510817928179784e-07,
#                                learning_rate=0.1305311350875627, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=43,
#                                n_iter_no_change=0, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42, strategy='weighting'),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d0d97190>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d0dc1690>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d0d7fed0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=2.6510817928179784e-07,
#                                learning_rate=0.1305311350875627, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=43,
#                                n_iter_no_change=0, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 212,
#              'rank': 30,
#              'voting_model': VotingClassifier(estimators=None, voting='soft')},
#     213: {   'cost': 0.0030864197530864135,
#              'ensemble_weight': 0.04,
#              'estimators': [   {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d15e44d0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d22d0850>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d15e0d90>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5533096433992108e-06,
#                                learning_rate=0.044065049113033036, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=50,
#                                n_iter_no_change=8, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d427cad0>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d47c0910>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d4279ed0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5533096433992108e-06,
#                                learning_rate=0.044065049113033036, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=50,
#                                n_iter_no_change=8, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d1c11710>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d1bf8850>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d1c11310>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5533096433992108e-06,
#                                learning_rate=0.044065049113033036, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=50,
#                                n_iter_no_change=8, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d0ec0150>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d0eaa510>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d0ebbd90>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5533096433992108e-06,
#                                learning_rate=0.044065049113033036, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=50,
#                                n_iter_no_change=8, random_state=42,
#                                validation_fraction=None, warm_start=True)},
#                                {   'balancing': Balancing(random_state=42),
#                                    'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7f72d036d190>,
#                                    'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f72d0420390>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f72d03d8ed0>,
#                                    'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=1.5533096433992108e-06,
#                                learning_rate=0.044065049113033036, max_iter=512,
#                                max_leaf_nodes=17, min_samples_leaf=50,
#                                n_iter_no_change=8, random_state=42,
#                                validation_fraction=None, warm_start=True)}],
#              'model_id': 213,
#              'rank': 31,
#              'voting_model': VotingClassifier(estimators=None, voting='soft')}}

# %%
for run_key in estimator_askl.automl_.runhistory_.data:
    print('#########')
    print(run_key)
    print(estimator_askl.automl_.runhistory_.data[run_key])
# Out:
# #########
# RunKey(config_id=1, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.018518518518518476, time=10.526482582092285, status=<StatusType.SUCCESS: 1>, starttime=1651513462.1403139, endtime=1651513472.687515, additional_info={'duration': 10.192305326461792, 'num_run': 2, 'train_loss': 0.0, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=2, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.29320987654320985, time=11.30854082107544, status=<StatusType.SUCCESS: 1>, starttime=1651513472.7363832, endtime=1651513484.061751, additional_info={'duration': 11.12779450416565, 'num_run': 3, 'train_loss': 0.2932098765432099, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=3, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.0810185185185185, time=10.140499591827393, status=<StatusType.SUCCESS: 1>, starttime=1651513484.10659, endtime=1651513494.2657015, additional_info={'duration': 9.911866426467896, 'num_run': 4, 'train_loss': 0.04803240740740739, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=4, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.29320987654320985, time=3.138921022415161, status=<StatusType.SUCCESS: 1>, starttime=1651513494.3582497, endtime=1651513497.5122025, additional_info={'duration': 3.043888568878174, 'num_run': 5, 'train_loss': 0.2932098765432099, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=5, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.033179012345679, time=10.678643703460693, status=<StatusType.SUCCESS: 1>, starttime=1651513497.549757, endtime=1651513508.2436354, additional_info={'duration': 10.58308219909668, 'num_run': 6, 'train_loss': 0.02353395061728393, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=6, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.11496913580246917, time=5.957146406173706, status=<StatusType.SUCCESS: 1>, starttime=1651513508.3720253, endtime=1651513514.344478, additional_info={'duration': 5.857365846633911, 'num_run': 7, 'train_loss': 0.09529320987654319, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id
instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.28240740740740744, time=19.58994746208191, status=<StatusType.SUCCESS: 1>, starttime=1651514741.2369487, endtime=1651514760.8462477, additional_info={'duration': 19.32581853866577, 'num_run': 97, 'train_loss': 0.25154320987654316, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=97, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=1.0828518867492676, status=<StatusType.CRASHED: 3>, starttime=1651514761.9385178, endtime=1651514763.034812, additional_info={'traceback': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/__init__.py", line 42, in fit_predict_try_except_decorator\n    return ta(queue=queue, **kwargs)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/train_evaluator.py", line 1383, in eval_cv\n    evaluator.fit_predict_and_loss(iterative=iterative)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/train_evaluator.py", line 510, in fit_predict_and_loss\n    add_model_to_self=self.num_cv_folds == 1,\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/train_evaluator.py", line 876, in _partial_fit_and_predict_standard\n    self.Y_train, \'iloc\') else self.Y_train[train_indices],\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/abstract_evaluator.py", line 175, in _fit_and_suppress_warnings\n    model.fit(X, y)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/pipeline/base.py", line 107, in fit\n    self.fit_estimator(X, y, **fit_params)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/pipeline/base.py", line 123, in fit_estimator\n    self._final_estimator.fit(X, y, **fit_params)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/pipeline/components/base.py", line 432, in fit\n    return self.choice.fit(X, y, **kwargs)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/pipeline/components/base.py", line 178, in fit\n    self.iterative_fit(X, y, n_iter=n_iter, refit=False, sample_weight=sample_weight)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/pipeline/components/classification/passive_aggressive.py", line 103, in iterative_fit\n    intercept_init=None\n  File "/usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py", line 524, in _partial_fit\n    max_iter=max_iter)\n  File "/usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py", line 631, in _fit_multiclass\n    for i, seed in enumerate(seeds))\n  File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 1046, in __call__\n    while self.dispatch_one_batch(iterator):\n  File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 861, in dispatch_one_batch\n    self._dispatch(tasks)\n  File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 779, in _dispatch\n    job = self._backend.apply_async(batch, callback=cb)\n  File "/usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py", line 208, in apply_async\n    result = ImmediateResult(func)\n  File "/usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py", line 572, in __init__\n    self.results = batch()\n  File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 263, in __call__\n    for func, args, kwargs in self.items]\n  File "/usr/local/lib/python3.7/dist-packages/joblib/parallel.py", line 263, in <listcomp>\n    for func, args, kwargs in self.items]\n  File "/usr/local/lib/python3.7/dist-packages/sklearn/utils/fixes.py", line 222, in __call__\n    return self.function(*args, **kwargs)\n  File "/usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py", line 442, in fit_binary\n    est.eta0, est.power_t, est.t_, intercept_decay, est.average)\n  File "sklearn/linear_model/_sgd_fast.pyx", line 640, in sklearn.linear_model._sgd_fast._plain_sgd\nValueError: Floating-point under-/overflow occurred at epoch #2. Scaling input data with StandardScaler or MinMaxScaler might help.\n', 'error': "ValueError('Floating-point under-/overflow occurred at epoch #2. Scaling input data with StandardScaler or MinMaxScaler might help.')", 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=98, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.19367283950617287, time=4.764608383178711, status=<StatusType.SUCCESS: 1>, starttime=1651514764.0878143, endtime=1651514768.8679683, additional_info={'duration': 4.667335510253906, 'num_run': 99, 'train_loss': 0.18730709876543208, 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=99, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.0030864197530864135, time=14.58881688117981, status=<StatusType.SUCCESS: 1>, starttime=1651514776.2690861, endtime=1651514790.8746343, additional_info={'duration': 14.321589708328247, 'num_run': 100, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=100, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.0030864197530864135, time=12.903701305389404, status=<StatusType.SUCCESS: 1>, starttime=1651514800.7990868, endtime=1651514813.719494, additional_info={'duration': 12.688457727432251, 'num_run': 101, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=101, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0.003858024691358017, time=13.126013278961182, status=<StatusType.SUCCESS: 1>, starttime=1651514823.6176972, endtime=1651514836.7608886, additional_info={'duration': 12.945140361785889, 'num_run': 102, 'train_loss': 0.00019290123456790927, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=102, instance_id='{"task_id": "car"}', seed=0, budget=0.0)
# RunValue(cost=0