# %%
# %pip install tpot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tpot
#   Using cached TPOT-0.11.7-py3-none-any.whl (87 kB)
# Collecting deap>=1.2
#   Using cached deap-1.3.1-cp38-cp38-manylinux2010_x86_64.whl (157 kB)
# Requirement already satisfied: numpy>=1.16.3 in ./.local/lib/python3.8/site-packages (from tpot) (1.22.3)
# Collecting xgboost>=1.1.0
#   Using cached xgboost-1.6.0-py3-none-manylinux2014_x86_64.whl (193.7 MB)
# Requirement already satisfied: tqdm>=4.36.1 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (4.47.0)
# Requirement already satisfied: scipy>=1.3.1 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (0.23.1)
# Requirement already satisfied: joblib>=0.13.2 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (0.16.0)
# Processing ./.cache/pip/wheels/a8/bb/8f/6b9328d23c2dcedbfeb8498b9f650d55d463089e3b8fc0bfb2/stopit-1.1.2-py3-none-any.whl
# Requirement already satisfied: pandas>=0.24.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from tpot) (1.1.3)
# Collecting update-checker>=0.16
#   Using cached update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (2.1.0)
# Requirement already satisfied: pytz>=2017.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: requests>=2.3.0 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.24.0)
# Requirement already satisfied: six>=1.5 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Installing collected packages: deap, xgboost, stopit, update-checker, tpot
# Successfully installed deap-1.3.1 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0 xgboost-1.6.0
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/share/apps/anaconda3/2020.07/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tpot
import sklearn
import sklearn.datasets
import sklearn.model_selection
import timeit
from tpot import TPOTClassifier
import pandas as pd
print('tpot: %s' % tpot.__version__)
# Out:
# tpot: 0.11.7
# /home/av3040/.local/lib/python3.8/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
def dataSetup(name):
  X,y = sklearn.datasets.fetch_openml(name, as_frame=True, return_X_y=True)
  train = pd.concat([X, y], axis=1, join='inner')
  train.dropna()
  train = train.apply(lambda x: pd.factorize(x)[0])
  X,y = train.iloc[:,:-1], train.iloc[:, -1]
  # X = X.apply(lambda x: pd.factorize(x)[0])
  X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,random_state=42)
  return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = dataSetup("spambase")
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 1173               0                  2              3             0
# 1954              24                  2              3             0
# 256                0                  2              8             0
# 3341               0                  2            111             0
# 4469               0                  2              3             0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 1173              9               0               153                   0
# 1954              9               0                 0                   0
# 256              13               0                 0                  47
# 3341            134              93                 0                   0
# 4469              9               0                 0                   0
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  \
# 1173                0               0  ...                     0
# 1954                0               0  ...                     0
# 256                 0               8  ...                     0
# 3341              127               0  ...                     0
# 4469                0               0  ...                     0
#
#       char_freq_%3B  char_freq_%28  char_freq_%5B  char_freq_%21  \
# 1173              0              0              0            579
# 1954              0            130              0              5
# 256               0              0              0            183
# 3341             36            250              0            859
# 4469              0              0              0              5
#
#       char_freq_%24  char_freq_%23  capital_run_length_average  \
# 1173              0              0                         864
# 1954              0              0                        1308
# 256               0              0                         215
# 3341            374            247                        1846
# 4469              0              0                         346
#
#       capital_run_length_longest  capital_run_length_total
# 1173                          27                       567
# 1954                          35                        88
# 256                           93                       181
# 3341                          44                       865
# 4469                          64                       375
#
# [5 rows x 57 columns]

# %%
model = TPOTClassifier(max_time_mins = 60,generations = None,scoring='accuracy', verbosity=2, random_state=1, n_jobs=-1)

# %%
start = timeit.default_timer()
model.fit(X_train, y_train)
stop = timeit.default_timer()
print(model.score(X_test,y_test))
model.export('tpot_sonar_best_model.py')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', style=ProgressStyle(description_w…
# Generation 1 - Current best internal CV score: 0.9739130434782608
#
# Generation 2 - Current best internal CV score: 0.9756521739130435
#
# Generation 3 - Current best internal CV score: 0.9756521739130435
#
# Generation 4 - Current best internal CV score: 0.9762318840579709
#
# Generation 5 - Current best internal CV score: 0.9773913043478262
#
# Generation 6 - Current best internal CV score: 0.9773913043478262
#
# Generation 7 - Current best internal CV score: 0.9773913043478262
#
# Generation 8 - Current best internal CV score: 0.9782608695652174
#
# Generation 9 - Current best internal CV score: 0.9788405797101449
#
# Generation 10 - Current best internal CV score: 0.9788405797101449
#
# Generation 11 - Current best internal CV score: 0.9797101449275362
#
# Generation 12 - Current best internal CV score: 0.9797101449275362
#
# Generation 13 - Current best internal CV score: 0.9805797101449276
#
# Generation 14 - Current best internal CV score: 0.9808695652173913
#
# Generation 15 - Current best internal CV score: 0.9808695652173913
#
# Generation 16 - Current best internal CV score: 0.9808695652173913
#
# Generation 17 - Current best internal CV score: 0.9808695652173913
#
# Generation 18 - Current best internal CV score: 0.9808695652173913
#
# Generation 19 - Current best internal CV score: 0.9808695652173913
#
# 61.34 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: GradientBoostingClassifier(input_matrix, learning_rate=0.1, max_depth=8, max_features=0.1, min_samples_leaf=15, min_samples_split=10, n_estimators=100, subsample=0.8500000000000001)
# 0.9826238053866203

# %%
print(stop - start)
# Out:
# 3681.468786374666
