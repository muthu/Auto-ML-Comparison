# %%
# %pip install auto-sklearn
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.14.7.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 7.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (57.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (4.2.0)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.21.6)
# Collecting scipy>=1.7.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 10.5 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.1.0)
# Collecting scikit-learn<0.25.0,>=0.24.0
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 11.8 MB/s
# Collecting dask>=2021.12
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.1 MB/s
# Collecting distributed>=2012.12
#   Downloading distributed-2022.2.0-py3-none-any.whl (837 kB)
#      |████████████████████████████████| 837 kB 45.0 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (3.13)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (1.3.5)
# Collecting liac-arff
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.7/dist-packages (from auto-sklearn) (3.1.0)
# Collecting ConfigSpace<0.5,>=0.4.21
#   Downloading ConfigSpace-0.4.21-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 38.2 MB/s
# Collecting pynisher<0.7,>=0.6.3
#   Downloading pynisher-0.6.4.tar.gz (11 kB)
# Collecting pyrfr<0.9,>=0.8.1
#   Downloading pyrfr-0.8.2-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 42.5 MB/s
# Collecting smac<1.3,>=1.2
#   Downloading smac-1.2.tar.gz (260 kB)
#      |████████████████████████████████| 260 kB 47.3 MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (3.0.8)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (0.29.28)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (0.11.2)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2021.12->auto-sklearn) (1.3.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 42.5 MB/s
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (5.4.8)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (5.1.1)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (1.7.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (7.1.2)
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (1.0.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2012.12->auto-sklearn) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->auto-sklearn) (2022.1)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->auto-sklearn) (1.15.0)
# Collecting emcee>=3.0.0
#   Downloading emcee-3.1.1-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.3 MB/s
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2012.12->auto-sklearn) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2012.12->auto-sklearn) (2.0.1)
# Building wheels for collected packages: auto-sklearn, pynisher, smac, liac-arff
#   Building wheel for auto-sklearn (setup.py) ... done
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.14.7-py3-none-any.whl size=6602873 sha256=3a04636c3f039170a8084130ec121fdb2a44d2072e8a4b542ad6d15d6247d37a
#   Stored in directory: /root/.cache/pip/wheels/ba/43/5c/2fbe6fd19e3af314cbc4aa808378068d8ddd6792064f4a2448
#   Building wheel for pynisher (setup.py) ... done
#   Created wheel for pynisher: filename=pynisher-0.6.4-py3-none-any.whl size=7043 sha256=2670edd65fe11cb1b90e5761ac3d6bd1ad41a11c19bcfb50b35f4c372a56ffea
#   Stored in directory: /root/.cache/pip/wheels/42/71/95/7555ec3253e1ba8add72ae5febf1b015d297f3b73ba296d6f6
#   Building wheel for smac (setup.py) ... done
#   Created wheel for smac: filename=smac-1.2-py3-none-any.whl size=215930 sha256=49074c5f9d92527ba19febfd532dced30813f178daecc93fa3fb9c61f480dee2
#   Stored in directory: /root/.cache/pip/wheels/ad/95/67/6afc6b04d3715070c853d0a9d7c7b1fb822def38671dfbbb9f
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11732 sha256=8308a2831982eaeadf77cfaa4336cead69dd0e6e4d35257a7d3e6c973328d208
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built auto-sklearn pynisher smac liac-arff
# Installing collected packages: locket, pyyaml, partd, fsspec, cloudpickle, scipy, dask, scikit-learn, pyrfr, pynisher, emcee, distributed, ConfigSpace, smac, liac-arff, distro, auto-sklearn
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.21 auto-sklearn-0.14.7 cloudpickle-2.0.0 dask-2022.2.0 distributed-2022.2.0 distro-1.7.0 emcee-3.1.1 fsspec-2022.3.0 liac-arff-2.5.0 locket-1.0.0 partd-1.2.0 pynisher-0.6.4 pyrfr-0.8.2 pyyaml-6.0 scikit-learn-0.24.2 scipy-1.7.3 smac-1.2

# %%
import sklearn.datasets
import sklearn.model_selection
import autosklearn.regression
import autosklearn.metrics
import pandas as pd

# %%
def dataSetup(name):
  X,y = sklearn.datasets.fetch_openml(data_id = name, as_frame=True, return_X_y=True)
  train = pd.concat([X, y], axis=1, join='inner')
  train.dropna()
  train = train.apply(lambda x: pd.factorize(x)[0])
  X,y = train.iloc[:,:-1], train.iloc[:, -1]
  # X = X.apply(lambda x: pd.factorize(x)[0])
  X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,random_state=42)
  return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = dataSetup(225)
X_train.head()
# Out:
#       theta1  theta2  theta3  thetad1  thetad2  thetad3  tau1  tau2
# 6936    6931    6927    6929     6930     6929     6929  6918  6915
# 380      380     380     379      380      380      380   380   380
# 4098    4098    4093    4091     4096     4096     4095  4093  4093
# 2684    2684    2682    2681     2684     2684     2684  2682  2683
# 1912    1912    1910    1910     1912     1912     1912  1911  1912

# %%
estimator_askl = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=3600,seed=42,resampling_strategy='cv',)
estimator_askl.fit(X_train, y_train, dataset_name='boston')
prediction = estimator_askl.predict(X_test)
# Out:
# [WARNING] [2022-05-04 20:53:31,235:Client-AutoMLSMBO(42)::boston] Dataset boston already in meta-data. Removing occurence.

# %%
(prediction == y_test).sum()/len(prediction)
# Out:
# 0.0

# %%
print(estimator_askl.sprint_statistics())
# Out:
# auto-sklearn results:
#   Dataset name: boston
#   Metric: r2
#   Best validation score: 0.999999
#   Number of target algorithm runs: 146
#   Number of successful target algorithm runs: 132
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 12

# %%
from pprint import pprint
pprint(estimator_askl.show_models(), indent=4)
# Out:
# {   97: {   'cost': 6.732467163277137e-07,
#             'ensemble_weight': 0.48,
#             'estimators': [   {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6ad9c10>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6050cd0>,
#                                   'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6057110>,
#                                   'sklearn_regressor': KNeighborsRegressor(n_neighbors=47, p=1, weights='distance')},
#                               {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5f97d50>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5faded0>,
#                                   'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5fb9090>,
#                                   'sklearn_regressor': KNeighborsRegressor(n_neighbors=47, p=1, weights='distance')},
#                               {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5f29390>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5ee4510>,
#                                   'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5ee4690>,
#                                   'sklearn_regressor': KNeighborsRegressor(n_neighbors=47, p=1, weights='distance')},
#                               {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5e7a990>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5e2eb10>,
#                                   'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5e2ec90>,
#                                   'sklearn_regressor': KNeighborsRegressor(n_neighbors=47, p=1, weights='distance')},
#                               {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5d53f90>,
#                                   'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5d1d150>,
#                                   'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5d1d390>,
#                                   'sklearn_regressor': KNeighborsRegressor(n_neighbors=47, p=1, weights='distance')}],
#             'model_id': 97,
#             'rank': 3,
#             'voting_model': VotingRegressor(estimators=None)},
#     108: {   'cost': 1.1490042128187545e-06,
#              'ensemble_weight': 0.02,
#              'estimators': [   {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6d749d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5c56cd0>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5c5d110>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=58, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5b9cd50>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5bb2e50>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5bb2fd0>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=58, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5b34310>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5af0410>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5af0590>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=58, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e5a82890>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5a3a990>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5a3ab10>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=58, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e595ce10>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e5910f90>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e5922150>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=58, p=1, weights='distance')}],
#              'model_id': 108,
#              'rank': 4,
#              'voting_model': VotingRegressor(estimators=None)},
#     140: {   'cost': 6.354001230588052e-07,
#              'ensemble_weight': 0.02,
#              'estimators': [   {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6c2cb10>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6db6610>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e701ced0>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=50, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6f75050>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6e9fad0>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6e9f910>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=50, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6d180d0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6d39990>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6d39d10>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=50, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6bfc250>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6ad9e10>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6c8f3d0>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=50, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6ce9b90>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6e1cb10>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6e1c590>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=50, p=1, weights='distance')}],
#              'model_id': 140,
#              'rank': 1,
#              'voting_model': VotingRegressor(estimators=None)},
#     146: {   'cost': 6.521273235662974e-07,
#              'ensemble_weight': 0.48,
#              'estimators': [   {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6c2c650>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6e4fb90>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6ec5510>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=55, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e6c8dad0>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6d62990>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6d62f10>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=55, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e634fa50>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e63144d0>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6314750>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=55, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e62b2f50>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e62709d0>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e6270c50>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=55, p=1, weights='distance')},
#                                {   'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66e61af490>,
#                                    'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66e6167ed0>,
#                                    'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66e617c190>,
#                                    'sklearn_regressor': KNeighborsRegressor(n_neighbors=55, p=1, weights='distance')}],
#              'model_id': 146,
#              'rank': 2,
#              'voting_model': VotingRegressor(estimators=None)}}

# %%
for run_key in estimator_askl.automl_.runhistory_.data:
    print('#########')
    print(run_key)
    print(estimator_askl.automl_.runhistory_.data[run_key])
# Out:
# #########
# RunKey(config_id=1, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=60.214600801467896, status=<StatusType.MEMOUT: 5>, starttime=1651697611.5728996, endtime=1651697672.8889544, additional_info={'error': 'Memout (used more than 3072 MB).', 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=2, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.00013958603189357947, time=22.182713985443115, status=<StatusType.SUCCESS: 1>, starttime=1651697672.9394155, endtime=1651697695.146645, additional_info={'duration': 21.932364225387573, 'num_run': 3, 'train_loss': 0.00011236727788201174, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=3, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=2.553816318511963, status=<StatusType.MEMOUT: 5>, starttime=1651697695.2015517, endtime=1651697698.78454, additional_info={'error': 'Memout (used more than 3072 MB).', 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=4, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=2.6949501037597656, status=<StatusType.MEMOUT: 5>, starttime=1651697698.822352, endtime=1651697702.5477262, additional_info={'error': 'Memout (used more than 3072 MB).', 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=5, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0013468264579977126, time=7.2724997997283936, status=<StatusType.SUCCESS: 1>, starttime=1651697702.6125865, endtime=1651697709.907683, additional_info={'duration': 7.117818593978882, 'num_run': 6, 'train_loss': 2.9144743787228806e-05, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=6, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0002293296845353309, time=2.4396793842315674, status=<StatusType.SUCCESS: 1>, starttime=1651697710.0742147, endtime=1651697712.5284767, additional_info={'duration': 2.344482660293579, 'num_run': 7, 'train_loss': 0.0, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=7, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0015703369956144239, time=13.739974737167358, status=<StatusType.SUCCESS: 1>, starttime=1651697712.7393105, endtime=1651697726.4986916, additional_info={'duration': 13.453341484069824, 'num_run': 8, 'train_loss': 6.386058586951699e-06, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=8, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.00031852549554285735, time=2.4926438331604004, status=<StatusType.SUCCESS: 1>, starttime=1651697726.7753417, endtime=1651697729.284046, additional_info={'duration': 2.3998680114746094, 'num_run': 9, 'train_loss': 0.00013285942803886941, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=9, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.00028254222779037504, time=124.10180640220642, status=<StatusType.SUCCESS: 1>, starttime=1651697729.6232698, endtime=1651697853.7472901, additional_info={'duration': 124.00339102745056, 'num_run': 10, 'train_loss': 1.4271704242419005e-05, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=10, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.00025820279292049106, time=58.8504593372345, status=<StatusType.SUCCESS: 1>, starttime=1651697854.1242473, endtime=1651697913.0546336, additional_info={'duration': 56.48274898529053, 'num_run': 11, 'train_loss': 2.289480439589908e-06, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=11, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0012469127628885366, time=20.082030773162842, status=<StatusType.SUCCESS: 1>, starttime=1651697913.5064476, endtime=1651697933.612483, additional_info={'duration': 19.82700228691101, 'num_run': 12, 'train_loss': 1.8487147784407767e-07, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=12, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=60.339773654937744, status=<StatusType.MEMOUT: 5>, starttime=1651697934.1289825, endtime=1651697995.6133032, additional_info={'error': 'Memout (used more than 3072 MB).', 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=13, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0031186018648737346, time=74.7657961845398, status=<StatusType.SUCCESS: 1>, starttime=1651697995.6626196, endtime=1651698070.450903, additional_info={'duration': 74.25349044799805, 'num_run': 14, 'train_loss': 1.1201645921641467e-06, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=14, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0015530031274897237, time=25.135347366333008, status=<StatusType.SUCCESS: 1>, starttime=1651698071.0360184, endtime=1651698096.1935747, additional_info={'duration': 24.905778408050537, 'num_run': 15, 'train_loss': 5.3853625143622e-06, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=15, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.9997490410777852, time=3.0893781185150146, status=<StatusType.SUCCESS: 1>, starttime=1651698096.8162355, endtime=1651698099.922732, additional_info={'duration': 2.9862146377563477, 'num_run': 16, 'train_loss': 0.9954410752215126, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=16, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0013143742446717, time=2.708099603652954, status=<StatusType.SUCCESS: 1>, starttime=1651698100.6038578, endtime=1651698103.3291113, additional_info={'duration': 2.6057615280151367, 'num_run': 17, 'train_loss': 1.0000000000000033, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=17, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0002680567506393863, time=2.888634204864502, status=<StatusType.SUCCESS: 1>, starttime=1651698103.3895726, endtime=1651698106.2959564, additional_info={'duration': 2.775768756866455, 'num_run': 18, 'train_loss': 0.0, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=18, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0007771940551795061, time=2.6926660537719727, status=<StatusType.SUCCESS: 1>, starttime=1651698107.0844562, endtime=1651698109.79419, additional_info={'duration': 2.5875439643859863, 'num_run': 19, 'train_loss': 0.0006188144133443701, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=19, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=1.1599602699279785, status=<StatusType.CRASHED: 3>, starttime=1651698110.5825605, endtime=1651698111.7595289, additional_info={'traceback': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/__init__.py", line 42, in fit_predict_try_except_decorator\n    return ta(queue=queue, **kwargs)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/train_evaluator.py", line 1383, in eval_cv\n    evaluator.fit_predict_and_loss(iterative=iterative)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/train_evaluator.py", line 548, in fit_predict_and_loss\n    train_pred,\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/evaluation/abstract_evaluator.py", line 339, in _loss\n    scoring_functions=scoring_functions)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/metrics/__init__.py", line 473, in calculate_loss\n    scoring_functions=scoring_functions,\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/metrics/__init__.py", line 433, in calculate_score\n    return _compute_scorer(metric, prediction, solution, task_type)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/metrics/__init__.py", line 560, in _compute_scorer\n    cprediction = sanitize_array(prediction)\n  File "/usr/local/lib/python3.7/dist-packages/autosklearn/metrics/util.py", line 12, in sanitize_array\n    maxi = np.nanmax(a[np.isfinite(a)])\n  File "<__array_function__ internals>", line 6, in nanmax\n  File "/usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py", line 434, in nanmax\n    res = np.fmax.reduce(a, axis=axis, out=out, **kwargs)\nValueError: zero-size array to reduction operation fmax which has no identity\n', 'error': "ValueError('zero-size array to reduction operation fmax which has no identity')", 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=20, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.00031638956717903506, time=2.5141918659210205, status=<StatusType.SUCCESS: 1>, starttime=1651698111.8156767, endtime=1651698114.3456926, additional_info={'duration': 2.4182729721069336, 'num_run': 21, 'train_loss': 0.00011334282262285047, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=21, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=2.5988645553588867, status=<StatusType.MEMOUT: 5>, starttime=1651698115.1957717, endtime=1651698118.8280919, additional_info={'error': 'Memout (used more than 3072 MB).', 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=22, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0013012479767529968, time=8.178023338317871, status=<StatusType.SUCCESS: 1>, starttime=1651698118.8833566, endtime=1651698127.0802765, additional_info={'duration': 7.873415470123291, 'num_run': 23, 'train_loss': 1.1730187059860522e-05, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=23, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0003191209682502605, time=2.54359769821167, status=<StatusType.SUCCESS: 1>, starttime=1651698127.9742486, endtime=1651698130.5347881, additional_info={'duration': 2.446244239807129, 'num_run': 24, 'train_loss': 0.00013286177625566902, 'configuration_origin': 'Initial design'})
# #########
# RunKey(config_id=24, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.
instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.0013822551196667802, time=9.627291440963745, status=<StatusType.SUCCESS: 1>, starttime=1651701065.134047, endtime=1651701074.780426, additional_info={'duration': 9.48299789428711, 'num_run': 138, 'train_loss': 6.7041501073482174e-06, 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=138, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=7.055858246939723e-07, time=2.7809104919433594, status=<StatusType.SUCCESS: 1>, starttime=1651701081.886292, endtime=1651701084.6866093, additional_info={'duration': 2.6757447719573975, 'num_run': 139, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=139, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=6.354001230588052e-07, time=3.231696367263794, status=<StatusType.SUCCESS: 1>, starttime=1651701098.041429, endtime=1651701101.2915428, additional_info={'duration': 2.895982503890991, 'num_run': 140, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=140, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=7.190809151252493e-07, time=2.8652641773223877, status=<StatusType.SUCCESS: 1>, starttime=1651701110.9870965, endtime=1651701113.8711455, additional_info={'duration': 2.758173704147339, 'num_run': 141, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=141, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.001301376592836, time=10.32755970954895, status=<StatusType.SUCCESS: 1>, starttime=1651701117.9092517, endtime=1651701128.2551267, additional_info={'duration': 10.232154369354248, 'num_run': 142, 'train_loss': 1.0000000483963474, 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=142, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=8.345706571384723e-07, time=2.9295482635498047, status=<StatusType.SUCCESS: 1>, starttime=1651701135.6614327, endtime=1651701138.6056814, additional_info={'duration': 2.825838804244995, 'num_run': 143, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=143, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=2.335762873852804e-06, time=9.052836418151855, status=<StatusType.SUCCESS: 1>, starttime=1651701142.6016405, endtime=1651701151.672595, additional_info={'duration': 8.942874908447266, 'num_run': 144, 'train_loss': 1.8808520222833358e-06, 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=144, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.3679457856819609e-06, time=3.2434732913970947, status=<StatusType.SUCCESS: 1>, starttime=1651701161.9178743, endtime=1651701165.1803515, additional_info={'duration': 3.1321189403533936, 'num_run': 145, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=145, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=6.521273235662974e-07, time=3.9692747592926025, status=<StatusType.SUCCESS: 1>, starttime=1651701175.5391881, endtime=1651701179.526058, additional_info={'duration': 3.869680643081665, 'num_run': 146, 'train_loss': 0.0, 'configuration_origin': 'Local Search'})
# #########
# RunKey(config_id=146, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=0.001393230910963917, time=6.055485963821411, status=<StatusType.SUCCESS: 1>, starttime=1651701183.5182614, endtime=1651701189.5923896, additional_info={'duration': 5.925980567932129, 'num_run': 147, 'train_loss': 5.314543689222693e-05, 'configuration_origin': 'Random Search'})
# #########
# RunKey(config_id=147, instance_id='{"task_id": "boston"}', seed=0, budget=0.0)
# RunValue(cost=1.0, time=0.0, status=<StatusType.STOP: 8>, starttime=1651701197.1110377, endtime=1651701197.111038, additional_info={})

# %%
print("Accuracy score", sklearn.metrics.r2_score(y_test, prediction))
# Out:
# Accuracy score 0.999999666478939

# %%
print(estimator_askl.leaderboard())
# Out:
#           rank  ensemble_weight                 type          cost  duration
# model_id
# 140          1             0.02  k_nearest_neighbors  6.354001e-07  3.231696
# 146          2             0.48  k_nearest_neighbors  6.521273e-07  3.969275
# 97           3             0.48  k_nearest_neighbors  6.732467e-07  2.783325
# 108          4             0.02  k_nearest_neighbors  1.149004e-06  3.365221

# %%
print("Accuracy score", sklearn.metrics.mean_squared_error(y_test, prediction))
# Out:
# Accuracy score 1.8877127483081704
