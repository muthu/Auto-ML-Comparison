# %%
# %pip install tpot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tpot in ./.local/lib/python3.8/site-packages (0.11.7)
# Requirement already satisfied: scipy>=1.3.1 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (1.5.0)
# Requirement already satisfied: numpy>=1.16.3 in ./.local/lib/python3.8/site-packages (from tpot) (1.22.3)
# Requirement already satisfied: update-checker>=0.16 in ./.local/lib/python3.8/site-packages (from tpot) (0.18.0)
# Requirement already satisfied: tqdm>=4.36.1 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (4.47.0)
# Requirement already satisfied: xgboost>=1.1.0 in ./.local/lib/python3.8/site-packages (from tpot) (1.6.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (0.23.1)
# Requirement already satisfied: joblib>=0.13.2 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from tpot) (0.16.0)
# Requirement already satisfied: stopit>=1.1.1 in ./.local/lib/python3.8/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: deap>=1.2 in ./.local/lib/python3.8/site-packages (from tpot) (1.3.1)
# Requirement already satisfied: pandas>=0.24.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from tpot) (1.1.3)
# Requirement already satisfied: requests>=2.3.0 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /share/apps/anaconda3/2020.07/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (2.1.0)
# Requirement already satisfied: pytz>=2017.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.25.10)
# Requirement already satisfied: six>=1.5 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/share/apps/anaconda3/2020.07/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tpot
import sklearn.datasets
import sklearn.model_selection
import timeit
from tpot import TPOTRegressor
import pandas as pd
print('tpot: %s' % tpot.__version__)
# Out:
# tpot: 0.11.7
# /home/av3040/.local/lib/python3.8/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
def dataSetup(name):
  X,y = sklearn.datasets.fetch_openml(data_id = name, as_frame=True, return_X_y=True)
  train = pd.concat([X, y], axis=1, join='inner')
  train.dropna()
  train = train.apply(lambda x: pd.factorize(x)[0])
  X,y = train.iloc[:,:-1], train.iloc[:, -1]
  # X = X.apply(lambda x: pd.factorize(x)[0])
  X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,random_state=42)
  return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = dataSetup(531)

# %%
model = TPOTRegressor(scoring = "neg_mean_squared_error",max_time_mins = 60,generations = None, verbosity=2, random_state=1, n_jobs=-1)

# %%
start = timeit.default_timer()
model.fit(X_train, y_train)
stop = timeit.default_timer()
print(model.score(X_test,y_test))
model.export('tpot_adult_best_model.py')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', style=ProgressStyle(description_w…
# Generation 1 - Current best internal CV score: -2367.254674566021
#
# Generation 2 - Current best internal CV score: -2356.964142268582
#
# Generation 3 - Current best internal CV score: -2341.799760810189
#
# Generation 4 - Current best internal CV score: -2341.799760810189
#
# Generation 5 - Current best internal CV score: -2307.615434956914
#
# Generation 6 - Current best internal CV score: -2307.615434956914
#
# Generation 7 - Current best internal CV score: -2307.615434956914
#
# Generation 8 - Current best internal CV score: -2307.615434956914
#
# Generation 9 - Current best internal CV score: -2301.6466470675746
#
# Generation 10 - Current best internal CV score: -2301.6466470675746
#
# Generation 11 - Current best internal CV score: -2301.6466470675746
#
# Generation 12 - Current best internal CV score: -2301.6466470675746
#
# Generation 68 - Current best internal CV score: -2294.773704650742
#
# Generation 69 - Current best internal CV score: -2294.773704650742
#
# Generation 70 - Current best internal CV score: -2294.773704650742
#
# Generation 71 - Current best internal CV score: -2294.773704650742
#
# Generation 72 - Current best internal CV score: -2294.773704650742
#
# Generation 73 - Current best internal CV score: -2294.773704650742
#
# Generation 74 - Current best internal CV score: -2293.569804637678
#
# Generation 75 - Current best internal CV score: -2293.569804637678
#
# Generation 76 - Current best internal CV score: -2293.569804637678
#
# Generation 77 - Current best internal CV score: -2293.569804637678
#
# Generation 78 - Current best internal CV score: -2293.569804637678
#
# Generation 79 - Current best internal CV score: -2293.569804637678
#
# Generation 80 - Current best internal CV score: -2293.569804637678
#
# Generation 81 - Current best internal CV score: -2293.569804637678
#
# Generation 82 - Current best internal CV score: -2293.569804637678
#
# Generation 83 - Current best internal CV score: -2293.569804637678
#
# Generation 84 - Current best internal CV score: -2293.569804637678
#
# Generation 85 - Current best internal CV score: -2293.569804637678
#
# Generation 86 - Current best internal CV score: -2293.569804637678
#
# Generation 87 - Current best internal CV score: -2293.569804637678
#
# Generation 88 - Current best internal CV score: -2293.569804637678
#
# Generation 89 - Current best internal CV score: -2291.3792938922775
#
# Generation 90 - Current best internal CV score: -2291.3792938922775
#
# Generation 91 - Current best internal CV score: -2291.3792938922775
#
# Generation 92 - Current best internal CV score: -2291.3792938922775
#
# Generation 93 - Current best internal CV score: -2291.3792938922775
#
# Generation 94 - Current best internal CV score: -2291.3792938922775
#
# Generation 95 - Current best internal CV score: -2291.3792938922775
#
# Generation 96 - Current best internal CV score: -2291.3792938922775
#
# Generation 97 - Current best internal CV score: -2291.3792938922775
#
# Generation 98 - Current best internal CV score: -2291.3792938922775
#
# Generation 99 - Current best internal CV score: -2291.3792938922775
#
# Generation 100 - Current best internal CV score: -2291.3792938922775
#
# Generation 101 - Current best internal CV score: -2291.3792938922775
#
# Generation 102 - Current best internal CV score: -2291.3792938922775
#
# Generation 103 - Current best internal CV score: -2291.3792938922775
#
# Generation 104 - Current best internal CV score: -2291.3792938922775
#
# Generation 105 - Current best internal CV score: -2291.3792938922775
#
# Generation 106 - Current best internal CV score: -2291.3792938922775
#
# Generation 107 - Current best internal CV score: -2291.3792938922775
#
# Generation 108 - Current best internal CV score: -2291.3792938922775
#
# Generation 109 - Current best internal CV score: -2291.3792938922775
#
# Generation 110 - Current best internal CV score: -2291.3792938922775
#
# Generation 111 - Current best internal CV score: -2291.3792938922775
#
# Generation 112 - Current best internal CV score: -2291.3792938922775
#
# Generation 113 - Current best internal CV score: -2291.3792938922775
#
# Generation 114 - Current best internal CV score: -2291.3792938922775
#
# Generation 115 - Current best internal CV score: -2291.3792938922775
#
# Generation 116 - Current best internal CV score: -2291.3792938922775
#
# Generation 117 - Current best internal CV score: -2291.3792938922775
#
# Generation 118 - Current best internal CV score: -2291.3792938922775
#
# Generation 119 - Current best internal CV score: -2291.3792938922775
#
# Generation 120 - Current best internal CV score: -2291.3792938922775
# Generation 121 - Current best internal CV score: -2291.3792938922775
#
# Generation 122 - Current best internal CV score: -2291.3792938922775
#
# Generation 123 - Current best internal CV score: -2291.3792938922775
#
# Generation 124 - Current best internal CV score: -2291.3792938922775
#
# Generation 125 - Current best internal CV score: -2291.3792938922775
#
# Generation 126 - Current best internal CV score: -2291.3792938922775
#
# Generation 127 - Current best internal CV score: -2291.3792938922775
#
# Generation 128 - Current best internal CV score: -2291.3792938922775
#
# Generation 129 - Current best internal CV score: -2291.3792938922775
#
# Generation 130 - Current best internal CV score: -2291.3792938922775
#
# Generation 131 - Current best internal CV score: -2291.3792938922775
#
# Generation 132 - Current best internal CV score: -2291.3792938922775
#
# Generation 133 - Current best internal CV score: -2291.3792938922775
#
# Generation 134 - Current best internal CV score: -2291.3792938922775
#
# Generation 135 - Current best internal CV score: -2291.3792938922775
#
# Generation 136 - Current best internal CV score: -2291.3792938922775
#
# Generation 137 - Current best internal CV score: -2291.3792938922775
#
# Generation 138 - Current best internal CV score: -2291.3792938922775
#
# Generation 139 - Current best internal CV score: -2291.3792938922775
#
# Generation 140 - Current best internal CV score: -2291.3792938922775
#
# Generation 141 - Current best internal CV score: -2291.3792938922775
#
# Generation 142 - Current best internal CV score: -2291.3792938922775
#
# Generation 143 - Current best internal CV score: -2291.3792938922775
#
# Generation 144 - Current best internal CV score: -2291.3792938922775
#
# Generation 145 - Current best internal CV score: -2291.3792938922775
#
# Generation 146 - Current best internal CV score: -2291.3792938922775
#
# Generation 147 - Current best internal CV score: -2291.3792938922775
#
# Generation 148 - Current best internal CV score: -2291.3792938922775
#
# Generation 149 - Current best internal CV score: -2291.3792938922775
#
# Generation 150 - Current best internal CV score: -2291.3792938922775
#
# Generation 151 - Current best internal CV score: -2291.3792938922775
#
# Generation 152 - Current best internal CV score: -2291.3792938922775
#
# Generation 153 - Current best internal CV score: -2291.3792938922775
#
# Generation 154 - Current best internal CV score: -2291.3792938922775
#
# Generation 155 - Current best internal CV score: -2291.3792938922775
#
# Generation 156 - Current best internal CV score: -2291.3792938922775
#
# Generation 157 - Current best internal CV score: -2291.3792938922775
#
# Generation 158 - Current best internal CV score: -2291.3792938922775
#
# Generation 159 - Current best internal CV score: -2291.3792938922775
#
# Generation 160 - Current best internal CV score: -2291.3792938922775
#
# Generation 161 - Current best internal CV score: -2291.3792938922775
#
# Generation 162 - Current best internal CV score: -2291.3792938922775
#
# Generation 163 - Current best internal CV score: -2291.3792938922775
#
# Generation 164 - Current best internal CV score: -2291.3792938922775
#
# Generation 165 - Current best internal CV score: -2291.3792938922775
#
# Generation 166 - Current best internal CV score: -2291.3792938922775
#
# Generation 167 - Current best internal CV score: -2291.3792938922775
#
# Generation 168 - Current best internal CV score: -2291.3792938922775
#
# Generation 169 - Current best internal CV score: -2291.3792938922775
#
# Generation 170 - Current best internal CV score: -2291.3792938922775
#
# 60.06 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestRegressor(RobustScaler(SGDRegressor(input_matrix, alpha=0.001, eta0=0.1, fit_intercept=False, l1_ratio=1.0, learning_rate=constant, loss=squared_loss, penalty=elasticnet, power_t=1.0)), bootstrap=True, max_features=0.25, min_samples_leaf=11, min_samples_split=8, n_estimators=100)
# -2637.4432771227634

# %%
print(stop - start)
# Out:
# 3603.946673668921
